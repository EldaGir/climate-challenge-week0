# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/kenya.csv")
df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  19.56    28.99    12.09      16.90         0.00  45.32  3.12
# 1  2015    2  19.63    29.77    11.04      18.73         0.00  38.76  3.23
# 2  2015    3  20.40    30.57    11.71      18.86         0.00  41.75  3.46
# 3  2015    4  21.33    31.20    13.02      18.18         3.49  51.87  2.29
# 4  2015    5  20.41    29.52    12.38      17.14         1.79  48.04  1.77
#
#    WS2M_MAX     PS  QV2M
# 0      4.76  83.68  6.88
# 1      4.35  83.67  5.85
# 2      4.68  83.69  6.65
# 3      4.00  83.62  8.60
# 4      4.05  83.54  7.64

# %%
df["Country"] = "Kenya"

# %%
df["Date"] = pd.to_datetime(df["YEAR"] * 1000 + df["DOY"], format="%Y%j")
df.head()
# Out:
#    YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0  2015    1  19.56    28.99    12.09      16.90         0.00  45.32  3.12
# 1  2015    2  19.63    29.77    11.04      18.73         0.00  38.76  3.23
# 2  2015    3  20.40    30.57    11.71      18.86         0.00  41.75  3.46
# 3  2015    4  21.33    31.20    13.02      18.18         3.49  51.87  2.29
# 4  2015    5  20.41    29.52    12.38      17.14         1.79  48.04  1.77
#
#    WS2M_MAX     PS  QV2M       Date
# 0      4.76  83.68  6.88 2015-01-01
# 1      4.35  83.67  5.85 2015-01-02
# 2      4.68  83.69  6.65 2015-01-03
# 3      4.00  83.62  8.60 2015-01-04
# 4      4.05  83.54  7.64 2015-01-05

# %%
df["Month"] = df["Date"].dt.month
df[["YEAR", "DOY", "Date", "Month"]].head()
# Out:
#    YEAR  DOY       Date  Month
# 0  2015    1 2015-01-01      1
# 1  2015    2 2015-01-02      1
# 2  2015    3 2015-01-03      1
# 3  2015    4 2015-01-04      1
# 4  2015    5 2015-01-05      1

# %%
df.replace(-999, np.nan, inplace=True)
# Out:
#       YEAR  DOY    T2M  T2M_MAX  T2M_MIN  T2M_RANGE  PRECTOTCORR   RH2M  WS2M  \
# 0     2015    1  19.56    28.99    12.09      16.90         0.00  45.32  3.12
# 1     2015    2  19.63    29.77    11.04      18.73         0.00  38.76  3.23
# 2     2015    3  20.40    30.57    11.71      18.86         0.00  41.75  3.46
# 3     2015    4  21.33    31.20    13.02      18.18         3.49  51.87  2.29
# 4     2015    5  20.41    29.52    12.38      17.14         1.79  48.04  1.77
# ...    ...  ...    ...      ...      ...        ...          ...    ...   ...
# 4103  2026   86  19.37    25.40    15.39      10.01         2.67  81.97  2.47
# 4104  2026   87  19.66    26.40    15.24      11.16         0.59  77.40  1.98
# 4105  2026   88  19.72    26.54    14.41      12.13         0.82  77.71  1.77
# 4106  2026   89  19.68    26.81    13.86      12.95         4.59  79.29  2.01
# 4107  2026   90  19.59    25.54    15.37      10.17         1.29  80.88  2.15
#
#       WS2M_MAX     PS   QV2M       Date  Month
# 0         4.76  83.68   6.88 2015-01-01      1
# 1         4.35  83.67   5.85 2015-01-02      1
# 2         4.68  83.69   6.65 2015-01-03      1
# 3         4.00  83.62   8.60 2015-01-04      1
# 4         4.05  83.54   7.64 2015-01-05      1
# ...        ...    ...    ...        ...    ...
# 4103      3.90  84.08  13.40 2026-03-27      3
# 4104      3.37  84.02  12.68 2026-03-28      3
# 4105      3.25  83.88  12.92 2026-03-29      3
# 4106      3.32  83.87  13.16 2026-03-30      3
# 4107      3.58  83.92  13.40 2026-03-31      3
#
# [4108 rows x 14 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#  Duplicate Check
# - Checked for duplicate rows using df.duplicated().sum().
# - No duplicate rows were found in the dataset.
# - No need to remove.

# %%
df.describe()
# Out:
#               YEAR          DOY          T2M      T2M_MAX      T2M_MIN  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean   2020.131451   180.121227    20.427600    27.838717    14.673169
# min    2015.000000     1.000000    15.260000    18.880000     8.970000
# 25%    2017.000000    86.000000    19.460000    26.297500    13.700000
# 50%    2020.000000   179.000000    20.360000    27.875000    14.750000
# 75%    2023.000000   272.000000    21.400000    29.520000    15.750000
# max    2026.000000   366.000000    25.400000    34.270000    18.750000
# std       3.248907   106.294767     1.440824     2.358770     1.415691
#
#          T2M_RANGE  PRECTOTCORR         RH2M         WS2M     WS2M_MAX  \
# count  4108.000000  4108.000000  4108.000000  4108.000000  4108.000000
# mean     13.165548     1.468162    65.845355     3.061765     4.375241
# min       4.110000     0.000000    28.420000     0.610000     1.160000
# 25%      11.467500     0.100000    58.677500     2.420000     3.670000
# 50%      13.260000     0.380000    66.220000     3.140000     4.430000
# 75%      15.050000     1.360000    73.280000     3.720000     5.090000
# max      20.120000    51.650000    91.070000     5.280000     7.590000
# std       2.605174     3.180228     9.934196     0.853218     0.992156
#
#                 PS         QV2M                 Date        Month
# count  4108.000000  4108.000000                 4108  4108.000000
# mean     83.724335    11.052539  2020-08-15 12:00:00     6.423564
# min      83.310000     4.780000  2015-01-01 00:00:00     1.000000
# 25%      83.630000     9.880000  2017-10-23 18:00:00     3.000000
# 50%      83.720000    11.005000  2020-08-15 12:00:00     6.000000
# 75%      83.810000    12.350000  2023-06-08 06:00:00     9.000000
# max      84.170000    15.040000  2026-03-31 00:00:00    12.000000
# std       0.126391     1.607151                  NaN     3.477046

# %%
# ### Summary Statistics Interpretation
#
# - The dataset covers climate data from 2015 to 2026 of Kenya, with a total of 4108 observations, indicating a continuous daily record.
#
# - The average temperature (T2M) is approximately 20.43°C, with values ranging from about 15.26°C to 25.4°C.

# %%
df.isna().sum()
# Out:
# YEAR           0
# DOY            0
# T2M            0
# T2M_MAX        0
# T2M_MIN        0
# T2M_RANGE      0
# PRECTOTCORR    0
# RH2M           0
# WS2M           0
# WS2M_MAX       0
# PS             0
# QV2M           0
# Date           0
# Month          0
# dtype: int64

# %%
## Missing values analysis
#-No missing values were found in any of the columns.
# - This indicates that the dataset is complete and does not require imputation or removal of missing data.

# %%
cols = ["T2M", "T2M_MAX", "T2M_MIN", "PRECTOTCORR", "RH2M", "WS2M", "WS2M_MAX"]

# %%
from scipy.stats import zscore
z_scores = df[cols].apply(zscore)

# %%
outliers = (np.abs(z_scores)>3)
outlier_count = outliers.sum().sum()
outlier_count
# Out:
# np.int64(124)

# %%
rows_with_outliers = outliers.any(axis=1)
rows_with_outliers.sum()
# Out:
# np.int64(121)

# %%
#   Outliers were retained rather than removed.
#
# - Justification:
#   In climate data, extreme values such as high temperatures or heavy rainfall events are meaningful and represent real-world phenomena rather than errors. Removing them could distort the analysis and eliminate important climate patterns.

# %%
# no missing values were found in the dataset. Therefore, no forward-fill was required and no rows needed to be dropped based on missing value thresholds.

# %%
df.to_csv("../data/kenya_clean.csv", index=False)

# %%
### Data Export

# - The cleaned dataset was exported to a CSV file for future analysis.
# - No rows were removed, as the dataset was already complete and consistent.
# - The exported file is stored locally and excluded from version control.

# %%
monthly_temp = df.groupby("Month")["T2M"].mean()
monthly_temp.plot(kind="line", marker="o", title="Monthly Average Temperature (T2M)")
# Out:
# <Axes: title={'center': 'Monthly Average Temperature (T2M)'}, xlabel='Month'>

# %%
max_month = monthly_temp.idxmax()
min_month = monthly_temp.idxmin()

print("Warmest month:", max_month)
print("Coolest month:", min_month)
# Out:
# Warmest month: 3
# Coolest month: 7

# %%
monthly_rain = df.groupby("Month")["PRECTOTCORR"].sum()
monthly_rain.plot(kind="bar", title="Monthly Total Precipitation")
# Out:
# <Axes: title={'center': 'Monthly Total Precipitation'}, xlabel='Month'>

# %%
peak_rain_month = monthly_rain.idxmax()
print("Peak rainy month:", peak_rain_month)
# Out:
# Peak rainy month: 4

# %%
#  The warmest month is March, while the coolest month is July.
# The peak rainfall occurs in April followed by November and March.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr = df.select_dtypes(include="number").corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure()
plt.scatter(df["T2M"], df["RH2M"])
plt.xlabel("Temperature (T2M)")
plt.ylabel("Humidity (RH2M)")
plt.title("Temperature vs Humidity")
plt.show()

# %%
plt.figure()
plt.scatter(df["T2M_RANGE"], df["WS2M"])
plt.xlabel("Temperature Range")
plt.ylabel("Wind Speed (WS2M)")
plt.title("Temp Range vs Wind Speed")
plt.show()

# %%
plt.figure()
plt.hist(df["PRECTOTCORR"], bins=50)
plt.title("Distribution of Precipitation")
plt.xlabel("Precipitation")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure()
plt.hist(np.log1p(df["PRECTOTCORR"]), bins=50)
plt.title("Log-Scaled Distribution of Precipitation")
plt.xlabel("Log(Precipitation + 1)")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure()
plt.scatter(
    df["T2M"],
    df["RH2M"],
    s=df["PRECTOTCORR"]
)
plt.xlabel("Temperature (T2M)")
plt.ylabel("Humidity (RH2M)")
plt.title("Bubble Chart: Temp vs Humidity (size = precipitation)")
plt.show()
